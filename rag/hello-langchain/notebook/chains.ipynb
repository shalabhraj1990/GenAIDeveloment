# %% [markdown]
# ## Simple Chain

# %%
# !pip install langchain-google-vertexai
# Out:
# Requirement already satisfied: langchain-google-vertexai in c:\users\shala\appdata\local\programs\python\python311\lib\site-packages (2.0.7)
# Requirement already satisfied: google-cloud-aiplatform<2.0.0,>=1.70.0 in c:\users\shala\appdata\local\programs\python\python311\lib\site-packages (from langchain-google-vertexai) (1.78.0)
# Requirement already satisfied: google-cloud-storage<3.0.0,>=2.18.0 in c:\users\shala\appdata\local\programs\python\python311\lib\site-packages (from langchain-google-vertexai) (2.19.0)
# Requirement already satisfied: httpx<0.28.0,>=0.27.0 in c:\users\shala\appdata\local\programs\python\python311\lib\site-packages (from langchain-google-vertexai) (0.27.2)
# Requirement already satisfied: httpx-sse<0.5.0,>=0.4.0 in c:\users\shala\appdata\local\programs\python\python311\lib\site-packages (from langchain-google-vertexai) (0.4.0)
# Requirement already satisfied: langchain-core<0.4,>=0.3.15 in c:\users\shala\appdata\local\programs\python\python311\lib\site-packages (from langchain-google-vertexai) (0.3.31)
# Requirement already satisfied: pydantic<3,>=2 in c:\users\shala\appdata\local\programs\python\python311\lib\site-packages (from langchain-google-vertexai) (2.10.5)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1 in c:\users\shala\appdata\local\programs\python\python311\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform<2.0.0,>=1.70.0->langchain-google-vertexai) (2.24.1)
# Requirement already satisfied: google-auth<3.0.0dev,>=2.14.1 in c:\users\shala\appdata\local\programs\python\python311\lib\site-packages (from google-cloud-aiplatform<2.0.0,>=1.70.0->langchain-google-vertexai) (2.37.0)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in c:\users\shala\appdata\local\programs\python\python311\lib\site-packages (from google-cloud-aiplatform<2.0.0,>=1.70.0->langchain-google-vertexai) (1.26.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.2 in c:\users\shala\appdata\local\programs\python\python311\lib\site-packages (from google-cloud-aiplatform<2.0.0,>=1.70.0->langchain-google-vertexai) (5.29.3)
# Requirement already satisfied: packaging>=14.3 in c:\users\shala\appdata\local\programs\python\python311\lib\site-packages (from google-cloud-aiplatform<2.0.0,>=1.70.0->langchain-google-vertexai) (24.2)
# Requirement already satisfied: google-cloud-bigquery!=3.20.0,<4.0.0dev,>=1.15.0 in c:\users\shala\appdata\local\programs\python\python311\lib\site-packages (from google-cloud-aiplatform<2.0.0,>=1.70.0->langchain-google-vertexai) (3.29.0)
# Requirement already satisfied: google-cloud-resource-manager<3.0.0dev,>=1.3.3 in c:\users\shala\appdata\local\programs\python\python311\lib\site-packages (from google-cloud-aiplatform<2.0.0,>=1.70.0->langchain-google-vertexai) (1.14.0)
# Requirement already satisfied: shapely<3.0.0dev in c:\users\shala\appdata\local\programs\python\python311\lib\site-packages (from google-cloud-aiplatform<2.0.0,>=1.70.0->langchain-google-vertexai) (2.0.6)
# Requirement already satisfied: typing-extensions in c:\users\shala\appdata\local\programs\python\python311\lib\site-packages (from google-cloud-aiplatform<2.0.0,>=1.70.0->langchain-google-vertexai) (4.12.2)
# Requirement already satisfied: docstring-parser<1 in c:\users\shala\appdata\local\programs\python\python311\lib\site-packages (from google-cloud-aiplatform<2.0.0,>=1.70.0->langchain-google-vertexai) (0.16)
# Requirement already satisfied: google-cloud-core<3.0dev,>=2.3.0 in c:\users\shala\appdata\local\programs\python\python311\lib\site-packages (from google-cloud-storage<3.0.0,>=2.18.0->langchain-google-vertexai) (2.4.1)
# Requirement already satisfied: google-resumable-media>=2.7.2 in c:\users\shala\appdata\local\programs\python\python311\lib\site-packages (from google-cloud-storage<3.0.0,>=2.18.0->langchain-google-vertexai) (2.7.2)
# Requirement already satisfied: requests<3.0.0dev,>=2.18.0 in c:\users\shala\appdata\local\programs\python\python311\lib\site-packages (from google-cloud-storage<3.0.0,>=2.18.0->langchain-google-vertexai) (2.32.3)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in c:\users\shala\appdata\local\programs\python\python311\lib\site-packages (from google-cloud-storage<3.0.0,>=2.18.0->langchain-google-vertexai) (1.6.0)
# Requirement already satisfied: anyio in c:\users\shala\appdata\local\programs\python\python311\lib\site-packages (from httpx<0.28.0,>=0.27.0->langchain-google-vertexai) (4.8.0)
# Requirement already satisfied: certifi in c:\users\shala\appdata\local\programs\python\python311\lib\site-packages (from httpx<0.28.0,>=0.27.0->langchain-google-vertexai) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in c:\users\shala\appdata\local\programs\python\python311\lib\site-packages (from httpx<0.28.0,>=0.27.0->langchain-google-vertexai) (1.0.7)
# Requirement already satisfied: idna in c:\users\shala\appdata\local\programs\python\python311\lib\site-packages (from httpx<0.28.0,>=0.27.0->langchain-google-vertexai) (3.10)
# Requirement already satisfied: sniffio in c:\users\shala\appdata\local\programs\python\python311\lib\site-packages (from httpx<0.28.0,>=0.27.0->langchain-google-vertexai) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\shala\appdata\local\programs\python\python311\lib\site-packages (from httpcore==1.*->httpx<0.28.0,>=0.27.0->langchain-google-vertexai) (0.14.0)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\shala\appdata\local\programs\python\python311\lib\site-packages (from langchain-core<0.4,>=0.3.15->langchain-google-vertexai) (6.0.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\shala\appdata\local\programs\python\python311\lib\site-packages (from langchain-core<0.4,>=0.3.15->langchain-google-vertexai) (1.33)
# Requirement already satisfied: langsmith<0.4,>=0.1.125 in c:\users\shala\appdata\local\programs\python\python311\lib\site-packages (from langchain-core<0.4,>=0.3.15->langchain-google-vertexai) (0.1.147)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\shala\appdata\local\programs\python\python311\lib\site-packages (from langchain-core<0.4,>=0.3.15->langchain-google-vertexai) (8.5.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\shala\appdata\local\programs\python\python311\lib\site-packages (from pydantic<3,>=2->langchain-google-vertexai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in c:\users\shala\appdata\local\programs\python\python311\lib\site-packages (from pydantic<3,>=2->langchain-google-vertexai) (2.27.2)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in c:\users\shala\appdata\local\programs\python\python311\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform<2.0.0,>=1.70.0->langchain-google-vertexai) (1.66.0)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in c:\users\shala\appdata\local\programs\python\python311\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform<2.0.0,>=1.70.0->langchain-google-vertexai) (1.70.0)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in c:\users\shala\appdata\local\programs\python\python311\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform<2.0.0,>=1.70.0->langchain-google-vertexai) (1.70.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\shala\appdata\local\programs\python\python311\lib\site-packages (from google-auth<3.0.0dev,>=2.14.1->google-cloud-aiplatform<2.0.0,>=1.70.0->langchain-google-vertexai) (5.5.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\shala\appdata\local\programs\python\python311\lib\site-packages (from google-auth<3.0.0dev,>=2.14.1->google-cloud-aiplatform<2.0.0,>=1.70.0->langchain-google-vertexai) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\shala\appdata\local\programs\python\python311\lib\site-packages (from google-auth<3.0.0dev,>=2.14.1->google-cloud-aiplatform<2.0.0,>=1.70.0->langchain-google-vertexai) (4.9)
# Requirement already satisfied: python-dateutil<3.0dev,>=2.7.3 in c:\users\shala\appdata\local\programs\python\python311\lib\site-packages (from google-cloud-bigquery!=3.20.0,<4.0.0dev,>=1.15.0->google-cloud-aiplatform<2.0.0,>=1.70.0->langchain-google-vertexai) (2.9.0.post0)
# Requirement already satisfied: grpc-google-iam-v1<1.0.0dev,>=0.12.4 in c:\users\shala\appdata\local\programs\python\python311\lib\site-packages (from google-cloud-resource-manager<3.0.0dev,>=1.3.3->google-cloud-aiplatform<2.0.0,>=1.70.0->langchain-google-vertexai) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\shala\appdata\local\programs\python\python311\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4,>=0.3.15->langchain-google-vertexai) (3.0.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\shala\appdata\local\programs\python\python311\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-core<0.4,>=0.3.15->langchain-google-vertexai) (3.10.0)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\shala\appdata\local\programs\python\python311\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-core<0.4,>=0.3.15->langchain-google-vertexai) (1.0.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\shala\appdata\local\programs\python\python311\lib\site-packages (from requests<3.0.0dev,>=2.18.0->google-cloud-storage<3.0.0,>=2.18.0->langchain-google-vertexai) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\shala\appdata\local\programs\python\python311\lib\site-packages (from requests<3.0.0dev,>=2.18.0->google-cloud-storage<3.0.0,>=2.18.0->langchain-google-vertexai) (2.3.0)
# Requirement already satisfied: numpy<3,>=1.14 in c:\users\shala\appdata\local\programs\python\python311\lib\site-packages (from shapely<3.0.0dev->google-cloud-aiplatform<2.0.0,>=1.70.0->langchain-google-vertexai) (1.26.4)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in c:\users\shala\appdata\local\programs\python\python311\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0dev,>=2.14.1->google-cloud-aiplatform<2.0.0,>=1.70.0->langchain-google-vertexai) (0.6.1)
# Requirement already satisfied: six>=1.5 in c:\users\shala\appdata\local\programs\python\python311\lib\site-packages (from python-dateutil<3.0dev,>=2.7.3->google-cloud-bigquery!=3.20.0,<4.0.0dev,>=1.15.0->google-cloud-aiplatform<2.0.0,>=1.70.0->langchain-google-vertexai) (1.17.0)
# [notice] A new release of pip is available: 25.0.1 -> 25.3
# [notice] To update, run: C:\Users\shala\AppData\Local\Programs\Python\Python311\python.exe -m pip install --upgrade pip

# %%
from langchain.chat_models import init_chat_model
llm = init_chat_model("gemini-2.5-flash-lite",model_provider="google_vertexai")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File s:\Shalabh_Private\code\GIT\GenAIDeveloment\rag\hello-langchain\.venv\Lib\site-packages\langchain\chat_models\base.py:102, in _import_module(module, class_name)
#     101 try:
# --> 102     return importlib.import_module(module)
#     103 except ImportError as e:
#     104     # Extract package name from module path (e.g., "langchain_azure_ai.chat_models"
#     105     # becomes "langchain-azure-ai")
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\importlib\__init__.py:126, in import_module(name, package)
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1204, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1176, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1147, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:690, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:940, in exec_module(self, module)
#
# File <frozen importlib._bootstrap>:241, in _call_with_frames_removed(f, *args, **kwds)
#
# File s:\Shalabh_Private\code\GIT\GenAIDeveloment\rag\hello-langchain\.venv\Lib\site-packages\langchain_google_vertexai\__init__.py:43
#      35 from google.cloud.aiplatform_v1beta1.types import (
#      36     FunctionCallingConfig,
#      37     FunctionDeclaration,
#    (...)     40     Type,
#      41 )
# ---> 43 from langchain_google_vertexai._enums import (
#      44     HarmBlockThreshold,
#      45     HarmCategory,
#      46     Modality,
#      47     SafetySetting,
#      48 )
#      49 from langchain_google_vertexai.chains import create_structured_runnable
#
# File s:\Shalabh_Private\code\GIT\GenAIDeveloment\rag\hello-langchain\.venv\Lib\site-packages\langchain_google_vertexai\_enums.py:2
#       1 from google.cloud.aiplatform_v1beta1.types.content import Modality
# ----> 2 from vertexai.generative_models import (
#       3     HarmBlockThreshold,  # TODO: migrate to google-genai since this is deprecated
#       4     HarmCategory,
#       5     SafetySetting,
#       6 )
#       8 __all__ = ["HarmBlockThreshold", "HarmCategory", "Modality", "SafetySetting"]
#
# File s:\Shalabh_Private\code\GIT\GenAIDeveloment\rag\hello-langchain\.venv\Lib\site-packages\vertexai\__init__.py:20
#      18 import sys
# ---> 20 from google.cloud.aiplatform import version as aiplatform_version
#      22 __version__ = aiplatform_version.__version__
#
# File s:\Shalabh_Private\code\GIT\GenAIDeveloment\rag\hello-langchain\.venv\Lib\site-packages\google\cloud\aiplatform\__init__.py:24
#      21 __version__ = aiplatform_version.__version__
# ---> 24 from google.cloud.aiplatform import initializer
#      26 from google.cloud.aiplatform.datasets import (
#      27     ImageDataset,
#      28     TabularDataset,
#    (...)     31     VideoDataset,
#      32 )
#
# File s:\Shalabh_Private\code\GIT\GenAIDeveloment\rag\hello-langchain\.venv\Lib\site-packages\google\cloud\aiplatform\initializer.py:35
#      34 from google.cloud.aiplatform import __version__
# ---> 35 from google.cloud.aiplatform import compat
#      36 from google.cloud.aiplatform.constants import base as constants
#
# File s:\Shalabh_Private\code\GIT\GenAIDeveloment\rag\hello-langchain\.venv\Lib\site-packages\google\cloud\aiplatform\compat\__init__.py:18
#       1 # -*- coding: utf-8 -*-
#       2
#       3 # Copyright 2023 Google LLC
#    (...)     15 # limitations under the License.
#      16 #
# ---> 18 from google.cloud.aiplatform.compat import services
#      19 from google.cloud.aiplatform.compat import types
#
# File s:\Shalabh_Private\code\GIT\GenAIDeveloment\rag\hello-langchain\.venv\Lib\site-packages\google\cloud\aiplatform\compat\services\__init__.py:30
#      27 from google.cloud.aiplatform_v1beta1.services.example_store_service import (
#      28     client as example_store_service_client_v1beta1,
#      29 )
# ---> 30 from google.cloud.aiplatform_v1beta1.services.extension_execution_service import (
#      31     client as extension_execution_service_client_v1beta1,
#      32 )
#      33 from google.cloud.aiplatform_v1beta1.services.extension_registry_service import (
#      34     client as extension_registry_service_client_v1beta1,
#      35 )
#
# File s:\Shalabh_Private\code\GIT\GenAIDeveloment\rag\hello-langchain\.venv\Lib\site-packages\google\cloud\aiplatform_v1beta1\services\extension_execution_service\__init__.py:16
#       1 # -*- coding: utf-8 -*-
#       2 # Copyright 2025 Google LLC
#       3 #
#    (...)     14 # limitations under the License.
#      15 #
# ---> 16 from .client import ExtensionExecutionServiceClient
#      17 from .async_client import ExtensionExecutionServiceAsyncClient
#
# File s:\Shalabh_Private\code\GIT\GenAIDeveloment\rag\hello-langchain\.venv\Lib\site-packages\google\cloud\aiplatform_v1beta1\services\extension_execution_service\client.py:37
#      35 import warnings
# ---> 37 from google.cloud.aiplatform_v1beta1 import gapic_version as package_version
#      39 from google.api_core import client_options as client_options_lib
#
# File s:\Shalabh_Private\code\GIT\GenAIDeveloment\rag\hello-langchain\.venv\Lib\site-packages\google\cloud\aiplatform_v1beta1\__init__.py:45
#      44 from .services.example_store_service import ExampleStoreServiceAsyncClient
# ---> 45 from .services.extension_execution_service import ExtensionExecutionServiceClient
#      46 from .services.extension_execution_service import ExtensionExecutionServiceAsyncClient
#
# ImportError: cannot import name 'ExtensionExecutionServiceClient' from partially initialized module 'google.cloud.aiplatform_v1beta1.services.extension_execution_service' (most likely due to a circular import) (s:\Shalabh_Private\code\GIT\GenAIDeveloment\rag\hello-langchain\.venv\Lib\site-packages\google\cloud\aiplatform_v1beta1\services\extension_execution_service\__init__.py)
#
# The above exception was the direct cause of the following exception:
#
# ImportError                               Traceback (most recent call last)
# Cell In[8], line 2
#       1 from langchain.chat_models import init_chat_model
# ----> 2 llm = init_chat_model("gemini-2.5-flash-lite",model_provider="google_vertexai")
#
# File s:\Shalabh_Private\code\GIT\GenAIDeveloment\rag\hello-langchain\.venv\Lib\site-packages\langchain\chat_models\base.py:451, in init_chat_model(model, model_provider, configurable_fields, config_prefix, **kwargs)
#     443     warnings.warn(
#     444         f"{config_prefix=} has been set but no fields are configurable. Set "
#     445         f"`configurable_fields=(...)` to specify the model params that are "
#     446         f"configurable.",
#     447         stacklevel=2,
#     448     )
#     450 if not configurable_fields:
# --> 451     return _init_chat_model_helper(
#     452         cast("str", model),
#     453         model_provider=model_provider,
#     454         **kwargs,
#     455     )
#     456 if model:
#     457     kwargs["model"] = model
#
# File s:\Shalabh_Private\code\GIT\GenAIDeveloment\rag\hello-langchain\.venv\Lib\site-packages\langchain\chat_models\base.py:474, in _init_chat_model_helper(model, model_provider, **kwargs)
#     467 def _init_chat_model_helper(
#     468     model: str,
#     469     *,
#     470     model_provider: str | None = None,
#     471     **kwargs: Any,
#     472 ) -> BaseChatModel:
#     473     model, model_provider = _parse_model(model, model_provider)
# --> 474     creator_func = _get_chat_model_creator(model_provider)
#     475     return creator_func(model=model, **kwargs)
#
# File s:\Shalabh_Private\code\GIT\GenAIDeveloment\rag\hello-langchain\.venv\Lib\site-packages\langchain\chat_models\base.py:142, in _get_chat_model_creator(provider)
#     140 pkg, class_name, creator_func = _SUPPORTED_PROVIDERS[provider]
#     141 try:
# --> 142     module = _import_module(pkg, class_name)
#     143 except ImportError as e:
#     144     if provider != "ollama":
#
# File s:\Shalabh_Private\code\GIT\GenAIDeveloment\rag\hello-langchain\.venv\Lib\site-packages\langchain\chat_models\base.py:111, in _import_module(module, class_name)
#     106 pkg = module.split(".", maxsplit=1)[0].replace("_", "-")
#     107 msg = (
#     108     f"Initializing {class_name} requires the {pkg} package. Please install it "
#     109     f"with `pip install {pkg}`"
#     110 )
# --> 111 raise ImportError(msg) from e
#
# ImportError: Initializing ChatVertexAI requires the langchain-google-vertexai package. Please install it with `pip install langchain-google-vertexai`

# %%
from langchain_core.prompts import PromptTemplate
template = """
you are an experianced cook.
List the ingredients to cook the food item {food}
"""

prompt_template = PromptTemplate.from_template(template=template)

# %%
chain = prompt_template | llm
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 chain = prompt_template | llm
#
# NameError: name 'llm' is not defined

# %%
resonse = chain.invoke({"food":"pasta"})
print(resonse.content)
